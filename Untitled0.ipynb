# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhuvin7/zara_H-M_Analysis/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd = pd.read_csv("/zara_data.csv")

# %%
pd.columns
# Out:
# Index(['Product ID', 'Product Position', 'Promotion', 'Product Category',
#        'Seasonal', 'Sales Volume', 'brand', 'name', 'description', 'price',
#        'currency', 'scraped_at', 'terms'],
#       dtype='object')

# %%
pd = pd.dropna(subset=['Product ID','Product Position','Promotion','Seasonal','Sales Volume','scraped_at','terms'])

# %%
pd.columns
# Out:
# Index(['Product ID', 'Product Position', 'Promotion', 'Product Category',
#        'Seasonal', 'Sales Volume', 'brand', 'name', 'description', 'price',
#        'currency', 'scraped_at', 'terms'],
#       dtype='object')

# %%
df = pd.drop_duplicates(subset=['Product ID','Product Position','Promotion','Seasonal','Sales Volume','scraped_at','terms'])

# %%
df.columns
# Out:
# Index(['Product ID', 'Product Position', 'Promotion', 'Product Category',
#        'Seasonal', 'Sales Volume', 'brand', 'name', 'description', 'price',
#        'currency', 'scraped_at', 'terms'],
#       dtype='object')

# %%
df = df.drop(columns=['Product ID','Product Position','Promotion','Sales Volume','scraped_at','terms'])

# %%
df.columns
# Out:
# Index(['Product Category', 'Seasonal', 'brand', 'name', 'description', 'price',
#        'currency'],
#       dtype='object')

# %%
df = df.drop(columns=['Seasonal','currency'])

# %%
df.head()
# Out:
#   Product Category brand                  name  \
# 0         Clothing  Zara   BASIC PUFFER JACKET
# 1         Clothing  Zara         TUXEDO JACKET
# 2         Clothing  Zara  SLIM FIT SUIT JACKET
# 3         Clothing  Zara   STRETCH SUIT JACKET
# 4         Clothing  Zara   DOUBLE FACED JACKET
#
#                                          description   price
# 0  Puffer jacket made of tear-resistant ripstop f...   19.99
# 1  Straight fit blazer. Pointed lapel collar and ...  169.00
# 2  Slim fit jacket. Notched lapel collar. Long sl...  129.00
# 3  Slim fit jacket made of viscose blend fabric. ...  129.00
# 4  Jacket made of faux leather faux shearling wit...  139.00

# %%
df.columns = df.columns.str.upper()

# %%
df['NAME'] = df['NAME'].str.title().str.replace(' ', '_')
display(df.head())
# Out:
#   PRODUCT CATEGORY BRAND                  NAME  \
# 0         Clothing  Zara   Basic_Puffer_Jacket
# 1         Clothing  Zara         Tuxedo_Jacket
# 2         Clothing  Zara  Slim_Fit_Suit_Jacket
# 3         Clothing  Zara   Stretch_Suit_Jacket
# 4         Clothing  Zara   Double_Faced_Jacket
#
#                                          DESCRIPTION   PRICE
# 0  Puffer jacket made of tear-resistant ripstop f...   19.99
# 1  Straight fit blazer. Pointed lapel collar and ...  169.00
# 2  Slim fit jacket. Notched lapel collar. Long sl...  129.00
# 3  Slim fit jacket made of viscose blend fabric. ...  129.00
# 4  Jacket made of faux leather faux shearling wit...  139.00

# %%
import pandas as pd
pd = pd.read_csv("/handm.csv")

# %%
pd.columns
# Out:
# Index(['Unnamed: 0', 'productId', 'productName', 'brandName', 'url', 'price',
#        'stockState', 'comingSoon', 'colorName', 'isOnline', 'colors',
#        'colorShades', 'newArrival', 'mainCatCode', 'details', 'materials'],
#       dtype='object')

# %%
df = pd.drop( columns=['productId','url','stockState','comingSoon','colorName','isOnline','colors','colorShades','newArrival','mainCatCode','materials'])

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'productName', 'brandName', 'price', 'details'], dtype='object')

# %%
from numpy._core.defchararray import upper
df.columns = df.columns.str.upper()

# %%
df_zara = pd.read_csv("/zara_data.csv")

df_zara = df_zara.dropna(subset=['Product ID','Product Position','Promotion','Seasonal','Sales Volume','scraped_at','terms'])
df_zara = df_zara.drop_duplicates(subset=['Product ID','Product Position','Promotion','Seasonal','Sales Volume','scraped_at','terms'])
df_zara = df_zara.drop(columns=['Product ID','Product Position','Promotion','Sales Volume','scraped_at','terms','Seasonal','currency'])
df_zara.columns = df_zara.columns.str.upper()
df_zara['NAME'] = df_zara['NAME'].str.title().str.replace(' ', '_')
display(df_zara.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_375/2158337252.py in <cell line: 0>()
# ----> 1 df_zara = pd.read_csv("/zara_data.csv")
#       2
#       3 df_zara = df_zara.dropna(subset=['Product ID','Product Position','Promotion','Seasonal','Sales Volume','scraped_at','terms'])
#       4 df_zara = df_zara.drop_duplicates(subset=['Product ID','Product Position','Promotion','Seasonal','Sales Volume','scraped_at','terms'])
#       5 df_zara = df_zara.drop(columns=['Product ID','Product Position','Promotion','Sales Volume','scraped_at','terms','Seasonal','currency'])
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
df_zara = pd.read_csv("/zara_data.csv")

df_zara = df_zara.dropna(subset=['Product ID','Product Position','Promotion','Seasonal','Sales Volume','scraped_at','terms'])
df_zara = df_zara.drop_duplicates(subset=['Product ID','Product Position','Promotion','Seasonal','Sales Volume','scraped_at','terms'])
df_zara = df_zara.drop(columns=['Product ID','Product Position','Promotion','Sales Volume','scraped_at','terms','Seasonal','currency'])
df_zara.columns = df_zara.columns.str.upper()
df_zara['NAME'] = df_zara['NAME'].str.title().str.replace(' ', '_')
display(df_zara.head())

# %% [markdown]
# ## Prepare H&M Data
#
# ### Subtask:
# Rename the current H&M DataFrame to `df_hm` and display its head to confirm its state.

# %% [markdown]
# **Reasoning**:
# Rename the current H&M DataFrame from `df` to `df_hm` and then display its head to confirm the new name and its content.

# %%
df_hm = df
display(df_hm.head())

# %%
df_hm = df_hm.rename(columns={'PRODUCTNAME': 'NAME', 'BRANDNAME': 'BRAND', 'DETAILS': 'DESCRIPTION'})
df_hm = df_hm.drop(columns=['UNNAMED: 0'])
display(df_hm.head())
display(df_zara.columns)
display(df_hm.columns)

# %%
merged_df = pd.concat([df_zara, df_hm], ignore_index=True)
display(merged_df.head())
display(merged_df.tail())

# %%
df_hm['PRODUCT CATEGORY'] = 'Unknown'
display(df_zara.columns)
display(df_hm.columns)
